# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import ast
import operator

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
# pip install fuzzywuzzy
# pip install python-Levenshtein

# %% [markdown]
# ## Load the Input Data

# %%
raw_recipes = pd.read_csv("../../data/recommendation/RAW_recipes.csv")

# %%
# Load labels from Food 101
all_labels = pd.read_csv("../../data/food-101/meta/labels.txt", header=None, names = ['label'])
all_labels = all_labels['label'].str.lower().tolist()
all_labels
# Out:
# ['apple pie',
#  'baby back ribs',
#  'baklava',
#  'beef carpaccio',
#  'beef tartare',
#  'beet salad',
#  'beignets',
#  'bibimbap',
#  'bread pudding',
#  'breakfast burrito',
#  'bruschetta',
#  'caesar salad',
#  'cannoli',
#  'caprese salad',
#  'carrot cake',
#  'ceviche',
#  'cheesecake',
#  'cheese plate',
#  'chicken curry',
#  'chicken quesadilla',
#  'chicken wings',
#  'chocolate cake',
#  'chocolate mousse',
#  'churros',
#  'clam chowder',
#  'club sandwich',
#  'crab cakes',
#  'creme brulee',
#  'croque madame',
#  'cup cakes',
#  'deviled eggs',
#  'donuts',
#  'dumplings',
#  'edamame',
#  'eggs benedict',
#  'escargots',
#  'falafel',
#  'filet mignon',
#  'fish and chips',
#  'foie gras',
#  'french fries',
#  'french onion soup',
#  'french toast',
#  'fried calamari',
#  'fried rice',
#  'frozen yogurt',
#  'garlic bread',
#  'gnocchi',
#  'greek salad',
#  'grilled cheese sandwich',
#  'grilled salmon',
#  'guacamole',
#  'gyoza',
#  'hamburger',
#  'hot and sour soup',
#  'hot dog',
#  'huevos rancheros',
#  'hummus',
#  'ice cream',
#  'lasagna',
#  'lobster bisque',
#  'lobster roll sandwich',
#  'macaroni and cheese',
#  'macarons',
#  'miso soup',
#  'mussels',
#  'nachos',
#  'omelette',
#  'onion rings',
#  'oysters',
#  'pad thai',
#  'paella',
#  'pancakes',
#  'panna cotta',
#  'peking duck',
#  'pho',
#  'pizza',
#  'pork chop',
#  'poutine',
#  'prime rib',
#  'pulled pork sandwich',
#  'ramen',
#  'ravioli',
#  'red velvet cake',
#  'risotto',
#  'samosa',
#  'sashimi',
#  'scallops',
#  'seaweed salad',
#  'shrimp and grits',
#  'spaghetti bolognese',
#  'spaghetti carbonara',
#  'spring rolls',
#  'steak',
#  'strawberry shortcake',
#  'sushi',
#  'tacos',
#  'takoyaki',
#  'tiramisu',
#  'tuna tartare',
#  'waffles']

# %%
print(raw_recipes.shape)
raw_recipes.head()
# Out:
# (231637, 12)
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %%
raw_recipes['name'] = raw_recipes['name'].astype(str)
recipes = raw_recipes[['name','id','ingredients']]

# Convert ingredients into list format from string format
recipes["ingredients"] = recipes["ingredients"].apply(lambda x: ast.literal_eval(x))
recipes.head()
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_42200\523164786.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipes["ingredients"] = recipes["ingredients"].apply(lambda x: ast.literal_eval(x))
#                                          name      id  \
# 0  arriba   baked winter squash mexican style  137739
# 1            a bit different  breakfast pizza   31490
# 2                   all in the kitchen  chili  112140
# 3                          alouette  potatoes   59389
# 4          amish  tomato ketchup  for canning   44061
#
#                                          ingredients
# 0  [winter squash, mexican seasoning, mixed spice...
# 1  [prepared pizza crust, sausage patty, eggs, mi...
# 2  [ground beef, yellow onions, diced tomatoes, t...
# 3  [spreadable cheese with garlic and herbs, new ...
# 4  [tomato juice, apple cider vinegar, sugar, sal...

# %%
recipe_list = raw_recipes['name'].unique().tolist()
recipe_list[:5]
# Out:
# ['arriba   baked winter squash mexican style',
#  'a bit different  breakfast pizza',
#  'all in the kitchen  chili',
#  'alouette  potatoes',
#  'amish  tomato ketchup  for canning']

# %% [markdown]
# ## Extract Recipe -> Food-101 Label Mapping

# %% [markdown]
# Get the closest food-101 label for each recipe id in data

# %%
# Extract recipe name and id for each label in Food-101 dataset
MATCH_COUNT = 1
threshold = 80
all_recipe_matches = {}
for recipe in recipe_list:
    recipe_match = process.extract(recipe, all_labels, limit = MATCH_COUNT)
    name = recipe_match[0][0]
    score = recipe_match[0][1]
    if score >= threshold:
        all_recipe_matches[recipe] = name

# %%
matched_recipes = pd.DataFrame(list(all_recipe_matches.items()), columns=['name','label'])
matched_recipes.head()
# Out:
#                                name           label
# 0  a bit different  breakfast pizza           pizza
# 1           apple a day  milk shake       apple pie
# 2    backyard style  barbecued ribs  baby back ribs
# 3          bananas 4 ice cream  pie       ice cream
# 4           beat this  banana bread   bread pudding

# %%
matched_recipes = recipes.merge(matched_recipes, how='left', on = 'name')
matched_recipes.head()
# Out:
#                                          name      id  \
# 0  arriba   baked winter squash mexican style  137739
# 1            a bit different  breakfast pizza   31490
# 2                   all in the kitchen  chili  112140
# 3                          alouette  potatoes   59389
# 4          amish  tomato ketchup  for canning   44061
#
#                                          ingredients  label
# 0  [winter squash, mexican seasoning, mixed spice...    NaN
# 1  [prepared pizza crust, sausage patty, eggs, mi...  pizza
# 2  [ground beef, yellow onions, diced tomatoes, t...    NaN
# 3  [spreadable cheese with garlic and herbs, new ...    NaN
# 4  [tomato juice, apple cider vinegar, sugar, sal...    NaN

# %%
matched_recipes.to_csv("../../data/recommendation/recipe_label_mapping.csv", index = False)

# %% [markdown]
# ## Extract Food-101 Label -> Ingredients Mapping

# %% [markdown]
# Extract 1 recipe_id per label. Total 101 rows

# %%
# Extract recipe name and id for each label in Food-101 dataset
MATCH_COUNT = 1
all_ingr_matches = {}
for label in all_labels:
    ingr_match = process.extract(label, recipe_list, limit = MATCH_COUNT)
    ingr_match = ingr_match[0][0]
    all_ingr_matches[label] =ingr_match

# %%
matched_ingredients = pd.DataFrame(list(all_ingr_matches.items()), columns=['label','name'])
matched_ingredients.head()
# Out:
#             label                                      name
# 0       apple pie                                 apple pie
# 1  baby back ribs                            baby back ribs
# 2         baklava                                   baklava
# 3  beef carpaccio                            beef carpaccio
# 4    beef tartare  love is in the air  beef fondue   sauces

# %%
matched_ingredients = matched_ingredients.merge(recipes, how='inner', on = 'name')
matched_ingredients.head()
# Out:
#             label            name      id  \
# 0       apple pie       apple pie  124853
# 1       apple pie       apple pie   65988
# 2  baby back ribs  baby back ribs  502407
# 3         baklava         baklava   48804
# 4  beef carpaccio  beef carpaccio  189130
#
#                                          ingredients
# 0  [apple juice, raw honey, whole cloves, evercle...
# 1  [all-purpose flour, salt, shortening, cold wat...
# 2  [baby back ribs, orange juice, margarita mix, ...
# 3  [phyllo dough, nuts, butter, ground cinnamon, ...
# 4  [beef tenderloin, arugula, vinaigrette, kosher...

# %%
# Drop if duplicates
matched_ingredients = matched_ingredients.drop_duplicates(subset= ['label','name'])
matched_ingredients.shape
# Out:
# (101, 4)

# %%
matched_recipes.to_csv("../../data/recommendation/label_ingredients_mapping.csv", index = False)
